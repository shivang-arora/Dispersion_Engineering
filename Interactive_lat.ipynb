# %%
import numpy as np
import math
from matplotlib import pyplot as plt

import meep as mp
from meep import mpb
from func import *

# %%
import numpy as np
file=np.load('./Bandstructure/3d_latsweep_width6_res12_rad0.35.npz')
bands=file['arr_0']
grid1=file['arr_1']
grid2=file['arr_2']

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider


def plot_with_slider(i,j):
    x = np.linspace(0, 10, 100)
    
    
    #longitudnal_shift(offset1=grid1[i],  offset2=grid2[j], debug=True)
    ng_slow_bands = 1/np.absolute(np.gradient(bands[i][j], axis=1))/90
    plt.plot(bands[9][9][22], label='Band with no lateral displacement')
    plt.plot(bands[i][j][22])
    slow_band=ng_slow_bands[22]
    
    plt.title(f'Offset 1 = {np.round(grid1[i],3)},    Offset 2 = {np.round(grid2[j],3)}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.show()
    plot_band_structure(bands[i][j], band_index=22,zoom=True,freq='frequency')
    plot_group_index(bands[i][j][22],zoom=True,freq='frequency',cut=0)
    
#plt.plot(slow_band)
   
# Create slider widget with integer values
integer_slider = IntSlider(value=9, min=0, max=19, step=1, description='offset1')
integer_slider2 = IntSlider(value=9, min=0, max=19, step=1, description='offset2')
# Create interactive plot with slider
interact(plot_with_slider, i=integer_slider,j=integer_slider2)
# Out:
# interactive(children=(IntSlider(value=9, description='offset1', max=19), IntSlider(value=9, description='offse…
# <function __main__.plot_with_slider(i, j)>

# %%
import matplotlib.pyplot as plt

from func import *

l=np.zeros(
    (20,20))
f=np.zeros(
    (20,20))
group=np.zeros(
    (20,20))
for i in range(20):
    for j in range(20):
        l[i][j],f[i][j],group[i][j]=plot_band_structure(bands[i][j],22,zoom=True
                    ,freq='',plot=False
                   )
# Out:
# 0 group_index = 13.921111756730792 v= 0.07183334330438837
# 1 group_index = 14.170155191153889 v= 0.07057085730608495
# left= 0 center= 1 right= 3
# 2 group_index = 14.407814457343239 v= 0.06940677942242165
# left= 0 center= 2 right= 4
# 3 group_index = 14.989668367785237 v= 0.06671261668130905
# left= 0 center= 3 right= 4
# 4 group_index = 15.71425412753846 v= 0.06363649154989476
# left= 1 center= 4 right= 5
# 5 group_index = 16.605958851906557 v= 0.06021934709811643
# left= 3 center= 5 right= 6
# 6 group_index = 18.051101148348316 v= 0.05539828245278546
# left= 5 center= 6 right= 7
# 7 group_index = 19.39564622371605 v= 0.05155796246568206
# left= 6 center= 7 right= 8
# 8 group_index = 21.24888470334289 v= 0.04706129352015729
# left= 7 center= 8 right= 8
# 9 group_index = 23.47688989403277 v= 0.04259507986422745
# left= 8 center= 9 right= 9
# 10 group_index = 25.852294752108794 v= 0.0386812857268088
# left= 9 center= 10 right= 10
# ...

# %%
plot_band_structure(bands[-3][0],22,zoom=True
                    ,freq='',
                   )
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 group_index = 14.457180285623574 v= 0.06916978139882604
# 1 group_index = 8.69206101502911 v= 0.11504751269818958
# left= 1 center= 1 right= 6
# 2 group_index = 8.665002837819948 v= 0.11540677120558138
# left= 1 center= 2 right= 6
# 3 group_index = 8.82588865274534 v= 0.11330303829393368
# left= 1 center= 3 right= 6
# 4 group_index = 9.010666503789396 v= 0.11097958176339724
# left= 1 center= 4 right= 7
# 5 group_index = 9.231271138074574 v= 0.10832744321369554
# left= 1 center= 5 right= 7
# 6 group_index = 9.496812905589824 v= 0.10529848381149007
# flag
# left= 1 center= 6 right= 21
# 7 group_index = 9.81995056492933 v= 0.1018335065322395
# left= 4 center= 7 right= 9
# 8 group_index = 10.22020863218259 v= 0.09784536069558138
# left= 5 center= 8 right= 9
# 9 group_index = 9.881527033072466 v= 0.1011989337936436
# ...

# %%
i,j=np.where(group>40)

# %%
g=group.copy()
for l,id in enumerate(i):
    g[id][j[l]]=40

plt.imshow(g)
plt.colorbar()
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/shivang/envs/mp/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
band=lateral_shift(offset1=0.13,offset2=-0.1,debug=True)
# Out:
# ...
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.521327)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      cylinder, center = (-0.736025,0,0)
#           radius 0.34, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-1.83205,-0.5,0)
#           radius 0.34, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-1.83205,0.5,0)
#           radius 0.34, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0.736025,0,0)
#           radius 0.34, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (1.83205,-0.5,0)
#           radius 0.34, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
# ...
