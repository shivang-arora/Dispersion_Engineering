# %%
import numpy as np
import math
from matplotlib import pyplot as plt

import meep as mp
from meep import mpb
from func import *

# %%
import numpy as np
file=np.load('./Bandstructure/3d_longsweep_width6_res11_rad0.35.npz')
bands=file['arr_0']
grid1=file['arr_1']
grid2=file['arr_2']

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider


def plot_with_slider(i,j):
    x = np.linspace(0, 10, 100)
    
    
    #longitudnal_shift(offset1=grid1[i],  offset2=grid2[j], debug=True)
    ng_slow_bands = 1/np.absolute(np.gradient(bands[i][j], axis=1))/90
    plt.plot(bands[9][9][22], label='Band with no longitudinal displacement')
    plt.plot(bands[i][j][22])
    
    slow_band=ng_slow_bands[22]
    
    plt.title(f'Offset 1 = {np.round(grid1[i],3)},    Offset 2 = {np.round(grid2[j],3)}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.show()
    plot_group_index(bands[i][j][22],zoom=True,freq='',cut=0)
    
#plt.plot(slow_band)
   
# Create slider widget with integer values
integer_slider = IntSlider(value=9, min=0, max=19, step=1, description='offset1')
integer_slider2 = IntSlider(value=9, min=0, max=19, step=1, description='offset2')
# Create interactive plot with slider
interact(plot_with_slider, i=integer_slider,j=integer_slider2)
# Out:
# interactive(children=(IntSlider(value=9, description='offset1', max=19), IntSlider(value=9, description='offse…
# <function __main__.plot_with_slider(i, j)>

# %%
file2=np.load(f'./Bandstructure/long_shift_offset10.25_offset2-0.25_width6_res11_rad0.35.npz')['arr_0']

# %%
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 group_index = -30.715912948705487 v= -0.03255641470497606
# 1 group_index = -23.7425981996904 v= -0.042118389554056467
# left= 1 center= 1 right= 1
# 2 group_index = -20.431812808493383 v= -0.04894328317183417
# left= 2 center= 2 right= 3
# 3 group_index = -18.606701780854724 v= -0.05374407628916508
# left= 2 center= 3 right= 5
# 4 group_index = -17.54573998534868 v= -0.056993891442312254
# left= 3 center= 4 right= 16
# 5 group_index = -16.89358893769434 v= -0.05919405306285862
# left= 4 center= 5 right= 15
# 6 group_index = -16.510184261624346 v= -0.0605686759247359
# left= 4 center= 6 right= 15
# 7 group_index = -16.31216440768175 v= -0.061303943180530875
# left= 4 center= 7 right= 14
# 8 group_index = -16.226840955918803 v= -0.06162628959737515
# left= 4 center= 8 right= 14
# 9 group_index = -16.274097658724905 v= -0.06144733926085775
# left= 4 center= 9 right= 14
# 10 group_index = -16.38282370943166 v= -0.061039538588472754
# left= 4 center= 10 right= 14
# 11 group_index = -16.580986147851526 v= -0.06031004375029735
# left= 4 center= 11 right= 15
# 12 group_index = -16.863266104160854 v= -0.05930049338148434
# left= 4 center= 12 right= 15
# 13 group_index = -17.20449355889764 v= -0.05812434969832812
# left= 3 center= 13 right= 16
# 14 group_index = -17.6480754953722 v= -0.05666340220848596
# left= 3 center= 14 right= 16
# 15 group_index = -18.150476752030816 v= -0.05509497153501008
# left= 10 center= 15 right= 17
# 16 group_index = -18.786660378528985 v= -0.05322925841268127
# left= 13 center= 16 right= 18
# 17 group_index = -19.48873874569778 v= -0.05131168379076117
# left= 14 center= 17 right= 19
# 18 group_index = -20.365487695032602 v= -0.049102678756075775
# left= 16 center= 18 right= 19
# 19 group_index = -21.37016857565555 v= -0.04679420269708022
# flag
# left= 17 center= 19 right= 20
# 20 group_index = -22.586166782249613 v= -0.04427488779485576
# flag
# left= 18 center= 20 right= 20
# Bandwidth Product: 0.45322497904400416
# Bandwidth (BW): -0.08897785599520606
# group_index -17.54573998534868
# bandwidth um  -0.08706796796826666
# frequency= 0.2903088073505608
# (0.45322497904400416, 0.2903088073505608, -17.54573998534868)
